# %%
from random import randint
from random import random
from random import seed
import numpy as np

# %%
alpha = float(0.0001)
epsilon = float(0.1)
gamma = float(0.8)
numTraining = int(20)
w = [0.5,0.2, 0.1]

# %%
def get_next_r_c(r, c):
    prob = random()
    #80% of the time will take the policy action
    if prob <= 0.8: 
        if policy[r][c] == 'up':
            rnext = r - 1
            cnext = c
        elif policy[r][c] == 'left':
            rnext = r
            cnext = c - 1
        elif policy[r][c] == 'right':
            rnext = r
            cnext = c + 1
        elif policy[r][c] == 'down':
            rnext = r + 1
            cnext = c
            
    #20% of the time will make a perpendiclar action on the policy action
    else:
        if policy[r][c] == 'up' or policy[r][c] == 'down':
            prob2 = random()
            if prob2>0.5:
                #left
                rnext = r
                cnext = c - 1
            else:
                #right
                rnext = r
                cnext = c + 1
                
        elif policy[r][c] == 'right' or policy[r][c] == 'left':
            prob2 = random()
            if prob2>0.5:
                #up
                rnext = r - 1
                cnext = c
            else:
                #down
                rnext = r + 1
                cnext = c
                
    return rnext, cnext

# %%
def recursive_approximation(r, c):
    #updates delta values recursively for each step
    if policy[r][c] == 'exit':
        if positive_reward_position_row == r and positive_reward_position_col == c:
            return 1
        else:
            return -1
    
    rnext, cnext = get_next_r_c(r, c)
    
    while rnext >= rows or rnext < 0 or cnext >= cols or cnext < 0 or policy[rnext][cnext] == 'obstacle':
        rnext, cnext = get_next_r_c(r, c)
    
    value = recursive_approximation(rnext,cnext) + one_step_reward
    delta_rule(r,c, value)
    return value

# %%
def approximate_value(r,c):
    return w[0]+w[1]*c+w[2]*r

# %%
def delta_rule(r,c, current_observed_value):
        w[0] = w[0] + alpha * (current_observed_value - approximate_value(r,c))
        w[1] = w[1] + alpha * (current_observed_value - approximate_value(r,c)) * c
        w[2] = w[2] + alpha * (current_observed_value - approximate_value(r,c)) * r

# %%
def function_approximation():
    for i in range(iterations):
        r = randint(0, rows - 1)
        c = randint(0, cols - 1)
        while policy[r][c] == 'obstacle' or policy[r][c] == 'exit':
            r = randint(0, rows - 1)
            c = randint(0, cols - 1)
        recursive_approximation(r, c)

# %%
def view_utility_map():
    utility_map = np.zeros((rows,cols))
    for r in range(rows):
        for c in range(cols):
            utility_map[r,c] = w[0]+w[1]*c+w[2]*r
    print(utility_map)

# %%
iterations = 10000
w = [0.5,0.2, 0.1]
#should be read it from outside file
policy = [
    ['right', 'right',    'right', 'exit'],
    ['up',    'obstacle', 'up',    'exit'],
    ['up',    'left',     'up',  'left']
]
utility_map = []
positive_reward_position_row = 0
positive_reward_position_col = 3
negative_reward_position_row = 1
negative_reward_position_col = 3
rows = len(policy)
cols = len(policy[0]) 
one_step_reward = -0.04
function_approximation()
view_utility_map()

# print(w)
# Out:
# [[0.72896714 0.78809516 0.84722318 0.90635121]
#  [0.67400028 0.7331283  0.79225633 0.85138435]
#  [0.61903342 0.67816145 0.73728947 0.7964175 ]]

# %%
iterations = 10000
w = [0.5,0.2, 0.1]
policy = [
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'exit' ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'up'   , 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'up'   , 'up'   , 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'up',    'up'   , 'up'   , 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ]
]
utility_map = []

positive_reward_position_row = 0
positive_reward_position_col = 9

rows = len(policy)
cols = len(policy[0]) 


one_step_reward = -0.04
function_approximation()

view_utility_map()
# Out:
# [[0.50502943 0.55985548 0.61468153 0.66950758 0.72433362 0.77915967
#   0.83398572 0.88881177 0.94363782 0.99846386]
#  [0.46051589 0.51534194 0.57016799 0.62499403 0.67982008 0.73464613
#   0.78947218 0.84429823 0.89912427 0.95395032]
#  [0.41600235 0.4708284  0.52565445 0.58048049 0.63530654 0.69013259
#   0.74495864 0.79978468 0.85461073 0.90943678]
#  [0.37148881 0.42631486 0.4811409  0.53596695 0.590793   0.64561905
#   0.70044509 0.75527114 0.81009719 0.86492324]
#  [0.32697527 0.38180131 0.43662736 0.49145341 0.54627946 0.60110551
#   0.65593155 0.7107576  0.76558365 0.8204097 ]
#  [0.28246172 0.33728777 0.39211382 0.44693987 0.50176592 0.55659196
#   0.61141801 0.66624406 0.72107011 0.77589615]
#  [0.23794818 0.29277423 0.34760028 0.40242633 0.45725237 0.51207842
#   0.56690447 0.62173052 0.67655657 0.73138261]
#  [0.19343464 0.24826069 0.30308674 0.35791278 0.41273883 0.46756488
#   0.52239093 0.57721698 0.63204302 0.68686907]
#  [0.1489211  0.20374715 0.25857319 0.31339924 0.36822529 0.42305134
#   0.47787739 0.53270343 0.58752948 0.64235553]
#  [0.10440756 0.1592336  0.21405965 0.2688857  0.32371175 0.3785378
#   0.43336384 0.48818989 0.54301594 0.59784199]]

# %%
iterations = 10000
w = [0.5,0.2, 0.1]
policy = [
    ['down', 'down'  , 'down' , 'down' , 'down', 'down', 'down', 'down', 'down', 'left'],
    ['right', 'down' , 'down' , 'down' , 'down', 'down', 'down', 'down', 'left', 'left'],
    ['right', 'right', 'down' , 'down' , 'down', 'down', 'down', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'down' , 'down', 'down', 'left', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'right', 'exit', 'left', 'left', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'right', 'up'  , 'up'  , 'left', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'up'   , 'up'  , 'up'  , 'up'  , 'left', 'left', 'left'],
    ['right', 'right', 'up'   , 'up'   , 'up'  , 'up'  , 'up'  , 'up'  , 'left', 'left'],
    ['right', 'up'   , 'up'   , 'up'   , 'up'  , 'up'  , 'up'  , 'up'  , 'up'  , 'left'],
    ['up'   , 'up'   , 'up'   , 'up'   , 'up'  , 'up'  , 'up'  , 'up'  , 'up'  , 'up'  ]
]

utility_map = []

positive_reward_position_row = 4
positive_reward_position_col = 4

rows = len(policy)
cols = len(policy[0]) 


one_step_reward = -0.04
function_approximation()

view_utility_map()
# Out:
# [[0.66990558 0.67969798 0.68949038 0.69928278 0.70907517 0.71886757
#   0.72865997 0.73845237 0.74824476 0.75803716]
#  [0.6821243  0.6919167  0.70170909 0.71150149 0.72129389 0.73108629
#   0.74087868 0.75067108 0.76046348 0.77025588]
#  [0.69434301 0.70413541 0.71392781 0.72372021 0.7335126  0.743305
#   0.7530974  0.7628898  0.77268219 0.78247459]
#  [0.70656173 0.71635413 0.72614652 0.73593892 0.74573132 0.75552372
#   0.76531611 0.77510851 0.78490091 0.79469331]
#  [0.71878044 0.72857284 0.73836524 0.74815764 0.75795003 0.76774243
#   0.77753483 0.78732723 0.79711962 0.80691202]
#  [0.73099916 0.74079156 0.75058395 0.76037635 0.77016875 0.77996115
#   0.78975354 0.79954594 0.80933834 0.81913074]
#  [0.74321787 0.75301027 0.76280267 0.77259507 0.78238746 0.79217986
#   0.80197226 0.81176466 0.82155705 0.83134945]
#  [0.75543659 0.76522899 0.77502138 0.78481378 0.79460618 0.80439858
#   0.81419097 0.82398337 0.83377577 0.84356817]
#  [0.7676553  0.7774477  0.7872401  0.7970325  0.80682489 0.81661729
#   0.82640969 0.83620209 0.84599448 0.85578688]
#  [0.77987402 0.78966642 0.79945881 0.80925121 0.81904361 0.82883601
#   0.8386284  0.8484208  0.8582132  0.8680056 ]]
