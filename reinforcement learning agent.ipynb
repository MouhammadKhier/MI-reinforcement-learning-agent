# %%
from random import randint

# %%
Vs = [
    [0, 0, 0, 1],
    [0, 0, 0, -1],
    [0, 0, 0, 0]
]

# 0 for state
#-1 for obtacle
#1 for terminating
SOT = [
    [0, 0, 0, 1],
    [0, -1, 0, 1],
    [0, 0, 0, 0]
]

visited = [
    [False, False, False, False],
    [False, False, False, False],
    [False, False, False, False]
]

rows = len(Vs)
cols = len(Vs[0])

def TRlearn():
# Out:
# 3
# 4
