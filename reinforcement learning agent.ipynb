# %%
from random import randint
from random import random
from random import seed
import numpy as np

# %%
def get_next_r_c(r, c):
    prob = random()
    #80% of the time will take the policy action
    if prob <= 0.8: 
        if policy[r][c] == 'up':
            rnext = r - 1
            cnext = c
        elif policy[r][c] == 'left':
            rnext = r
            cnext = c - 1
        elif policy[r][c] == 'right':
            rnext = r
            cnext = c + 1
        elif policy[r][c] == 'down':
            rnext = r + 1
            cnext = c
            
    #20% of the time will make a perpendiclar action on the policy action
    else:
        if policy[r][c] == 'up' or policy[r][c] == 'down':
            prob2 = random()
            if prob2>0.5:
                #left
                rnext = r
                cnext = c - 1
            else:
                #right
                rnext = r
                cnext = c + 1
                
        elif policy[r][c] == 'right' or policy[r][c] == 'left':
            prob2 = random()
            if prob2>0.5:
                #up
                rnext = r - 1
                cnext = c
            else:
                #down
                rnext = r + 1
                cnext = c
                
    return rnext, cnext

# %%
def recursive_learning(r, c):
    if policy[r][c] == 'exit':
        return Vs[r][c]
    
    rnext, cnext = get_next_r_c(r, c)
    
    while rnext >= rows or rnext < 0 or cnext >= cols or cnext < 0 or policy[rnext][cnext] == 'obstacle':
        rnext, cnext = get_next_r_c(r, c)
    
    value = recursive_learning(rnext,cnext) + one_step_reward
    
    Vs[r][c] = Vs[r][c] + value
    count[r][c] += 1
    
    return value

# %%
def TRlearn():
    r = randint(0, rows - 1)
    c = randint(0, cols - 1)
    while policy[r][c] == 'obstacle' or policy[r][c] == 'exit':
        r = randint(0, rows - 1)
        c = randint(0, cols - 1)
    
    recursive_learning(r, c)

# %%
def main():
    for i in range(iterations):
        TRlearn()
        
    values = np.divide(Vs, count)
                
    print(values)

# %%
iterations = 1000
#should be read it from outside file
policy = [
    ['right', 'right',    'right', 'exit'],
    ['up',    'obstacle', 'up',    'exit'],
    ['up',    'left',     'left',  'left']
]

positive_reward_position_row = 0
positive_reward_position_col = 3
negative_reward_position_row = 1
negative_reward_position_col = 3

rows = len(policy)
cols = len(policy[0]) 

Vs = np.zeros((rows,cols))
Vs[positive_reward_position_row][positive_reward_position_col] = 1
Vs[negative_reward_position_row][negative_reward_position_col] = -1

one_step_reward = -0.04
 
count = np.zeros((rows, cols))
main()
# Out:
# [[0.8402751  0.88422721 0.92445703        inf]
#  [0.79574468        nan 0.64684211       -inf]
#  [0.72713376 0.67028902 0.61915493 0.48210526]]
# <ipython-input-5-769261bce2e7>:5: RuntimeWarning: divide by zero encountered in true_divide
#   values = np.divide(Vs, count)
# <ipython-input-5-769261bce2e7>:5: RuntimeWarning: invalid value encountered in true_divide
#   values = np.divide(Vs, count)

# %%
policy = [
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'exit' ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'right', 'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'right', 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'right', 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'right', 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'right', 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'right', 'up'   , 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'right', 'up'   , 'up'   , 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ],
    ['right', 'up',    'up'   , 'up'   , 'up'   , 'up'   , 'up'   , 'up',    'up'   , 'up'   ]
]

positive_reward_position_row = 0
positive_reward_position_col = 9

rows = len(policy)
cols = len(policy[0]) 

Vs = np.zeros((rows,cols))
Vs[positive_reward_position_row][positive_reward_position_col] = 1

one_step_reward = -0.04
 
count = np.zeros((rows, cols))
main()
# Out:
# [[0.55157895 0.60266667 0.64210526 0.6976     0.744      0.8041791
#   0.84779221 0.89488372 0.94484211        inf]
#  [0.48       0.57411765 0.5925     0.6464     0.69733333 0.73454545
#   0.78989011 0.84470588 0.8999596  0.94952077]
#  [0.432      0.49818182 0.54133333 0.57666667 0.60533333 0.67896104
#   0.74857143 0.79989822 0.84937143 0.9       ]
#  [0.42545455 0.4544     0.5        0.55666667 0.58688525 0.65411765
#   0.70123539 0.74979472 0.79190184 0.819     ]
#  [0.32       0.372      0.445      0.505      0.56       0.59857778
#   0.6497446  0.69367521 0.7443038  0.78193548]
#  [0.27111111 0.32421053 0.38909091 0.43407407 0.49854305 0.54341207
#   0.60299065 0.64       0.68615385 0.73714286]
#  [0.18666667 0.248      0.32       0.39938462 0.45012448 0.49590361
#   0.544      0.57886792 0.63510204 0.68340426]
#  [0.248      0.27851852 0.31358779 0.35294118 0.39512195 0.464
#   0.50095238 0.52842105 0.58243902 0.64275862]
#  [0.188      0.22057143 0.27255814 0.25666667 0.3712     0.42285714
#   0.43333333 0.5025     0.52148148 0.59619048]
#  [0.11636364 0.16       0.20571429 0.24       0.34222222 0.38666667
#   0.38666667 0.48888889 0.50222222 0.528     ]]
# <ipython-input-5-769261bce2e7>:5: RuntimeWarning: divide by zero encountered in true_divide
#   values = np.divide(Vs, count)

# %%
policy = [
    ['down', 'down'  , 'down' , 'down' , 'down', 'down', 'down', 'down', 'down', 'left'],
    ['right', 'down' , 'down' , 'down' , 'down', 'down', 'down', 'down', 'left', 'left'],
    ['right', 'right', 'down' , 'down' , 'down', 'down', 'down', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'down' , 'down', 'down', 'left', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'right', 'exit', 'left', 'left', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'right', 'up'  , 'up'  , 'left', 'left', 'left', 'left'],
    ['right', 'right', 'right', 'up'   , 'up'  , 'up'  , 'up'  , 'left', 'left', 'left'],
    ['right', 'right', 'up'   , 'up'   , 'up'  , 'up'  , 'up'  , 'up'  , 'left', 'left'],
    ['right', 'up'   , 'up'   , 'up'   , 'up'  , 'up'  , 'up'  , 'up'  , 'up'  , 'left'],
    ['up'   , 'up'   , 'up'   , 'up'   , 'up'  , 'up'  , 'up'  , 'up'  , 'up'  , 'up'  ]
]

positive_reward_position_row = 4
positive_reward_position_col = 4

rows = len(policy)
cols = len(policy[0]) 

Vs = np.zeros((rows,cols))
Vs[positive_reward_position_row][positive_reward_position_col] = 1

one_step_reward = -0.04
 
count = np.zeros((rows, cols))
main()
# Out:
# [[0.54666667 0.66       0.72       0.73714286 0.78823529 0.76
#   0.67333333 0.655      0.57       0.504     ]
#  [0.6        0.67866667 0.76137931 0.79428571 0.84333333 0.80148148
#   0.744      0.69246753 0.6368     0.56666667]
#  [0.67428571 0.74577778 0.7952     0.82363636 0.89       0.83333333
#   0.78567901 0.73210084 0.70352941 0.64      ]
#  [0.73230769 0.78588235 0.84601307 0.8924     0.94315789 0.89142857
#   0.84018265 0.79675676 0.72666667 0.68      ]
#  [0.74666667 0.81185185 0.89       0.94352941        inf 0.94193103
#   0.87009901 0.81666667 0.7625     0.72666667]
#  [0.74666667 0.77655172 0.83733333 0.88145985 0.93453376 0.89294461
#   0.84413793 0.78095238 0.75368421 0.72266667]
#  [0.696      0.72666667 0.78666667 0.832      0.88862745 0.83885714
#   0.79506849 0.74484472 0.69371429 0.652     ]
#  [0.655      0.679      0.73983471 0.79692308 0.82962963 0.79459459
#   0.75137255 0.694375   0.63908046 0.6       ]
#  [0.57333333 0.6416     0.69142857 0.73333333 0.764      0.73333333
#   0.7        0.66514286 0.58967742 0.51243243]
#  [0.50222222 0.6        0.65066667 0.72       0.74285714 0.67058824
#   0.65142857 0.64       0.552      0.47368421]]
# <ipython-input-5-769261bce2e7>:5: RuntimeWarning: divide by zero encountered in true_divide
#   values = np.divide(Vs, count)
